# %% [markdown]
# <a href="https://colab.research.google.com/github/Aroy2710/California-House-Price-Prediction-/blob/main/California_House_Price_Predicton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Loading Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# **Mounting Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')

print("\nGoogle Drive mounted successfully!")
print("You can now find your Google Drive files under '/content/drive/My Drive/'.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Google Drive mounted successfully!
# You can now find your Google Drive files under '/content/drive/My Drive/'.

# %% [markdown]
# **Performing Linear Regression**

# %%
data_root = "https://github.com/ageron/data/raw/main/"
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")
lifesat.head(5)
# Out:
#    Country  GDP per capita (USD)  Life satisfaction
# 0   Russia          26456.387938                5.8
# 1   Greece          27287.083401                5.4
# 2   Turkey          28384.987785                5.5
# 3   Latvia          29932.493910                5.9
# 4  Hungary          31007.768407                5.6

# %% [markdown]
# **Loading CSV**

# %%
data = pd.read_csv("/content/drive/MyDrive/California HPP /housing.csv")
